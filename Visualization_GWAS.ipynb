# %% [markdown]
# <a href="https://colab.research.google.com/github/magicmayonaise/Dan-Landayan.github.io/blob/master/Visualization_GWAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GWAS

# %% [markdown]
# First install gwaslab dependencies!

# %%
# !pip install gwaslab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.0/22.0 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 77.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.8/521.8 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.6/274.6 kB 13.1 MB/s eta 0:00:00
# ...

# %%
import sys
sys.path.insert(0,"/home/yunye/work/gwaslab/src")
import gwaslab as gl

# %%
mysumstats = gl.Sumstats("/SunL_22466613.txt",
             snpid="SNP",
             chrom="CHR",

             pos="BP",


             beta="BETA",
             se="SE",
             p="P",


             sep="\t")
# Out:
# 2024/10/16 16:06:08 GWASLab v3.4.48 https://cloufield.github.io/gwaslab/
# 2024/10/16 16:06:08 (C) 2022-2024, Yunye He, Kamatani Lab, MIT License, gwaslab@gmail.com
# 2024/10/16 16:06:08 Start to initialize gl.Sumstats from file :/SunL_22466613.txt
# 2024/10/16 16:06:21  -Reading columns          : BETA,CHR,SE,P,SNP,BP
# 2024/10/16 16:06:21  -Renaming columns to      : BETA,CHR,SE,P,SNPID,POS
# 2024/10/16 16:06:21  -Current Dataframe shape : 7245292  x  6
# 2024/10/16 16:06:21  -Initiating a status column: STATUS ...
# 2024/10/16 16:06:21  #WARNING! Version of genomic coordinates is unknown...
# 2024/10/16 16:06:23 Start to reorder the columns...v3.4.48
# 2024/10/16 16:06:23  -Current Dataframe shape : 7245292 x 7 ; Memory usage: 379.24 MB
# 2024/10/16 16:06:23  -Reordering columns to    : SNPID,CHR,POS,BETA,SE,P,STATUS
# 2024/10/16 16:06:23 Finished reordering the columns.
# 2024/10/16 16:06:23  -Column  : SNPID  CHR    POS   BETA    SE      P       STATUS
# ...

# %%
mysumstats.data
# Out:
#                   SNPID CHR        POS      BETA        SE         P   STATUS
# 0            rs61770171   1     750138 -0.109614  0.090246  0.224515  9999999
# 1           chr1:751343   1     751343 -0.109614  0.090246  0.224515  9999999
# 2           chr1:751756   1     751756 -0.109614  0.090246  0.224515  9999999
# 3             rs3094315   1     752566 -0.111955  0.090241  0.214746  9999999
# 4             rs3131972   1     752721 -0.111955  0.090241  0.214746  9999999
# ...                 ...  ..        ...       ...       ...       ...      ...
# 7245287        rs306937  23  154947398  0.001045  0.059655  0.986024  9999999
# 7245288        rs306933  23  154949953  0.001045  0.059655  0.986024  9999999
# 7245289  chrX:154953467  23  154953467 -0.013859  0.130067  0.915147  9999999
# 7245290      rs58956811  23  154965596 -0.059081  0.140293  0.673665  9999999
# 7245291        rs696802  23  154966891 -0.059081  0.140293  0.673665  9999999
#
# [7245292 rows x 7 columns]

# %%
mysumstats.get_lead(sig_level=5e-8)
# Out:
# 2024/10/16 16:06:38 Start to extract lead variants...v3.4.48
# 2024/10/16 16:06:38  -Current Dataframe shape : 7245292 x 7 ; Memory usage: 379.24 MB
# 2024/10/16 16:06:38  -Processing 7245292 variants...
# 2024/10/16 16:06:38  -Significance threshold : 5e-08
# 2024/10/16 16:06:38  -Sliding window size: 500  kb
# 2024/10/16 16:06:44  -Using P for extracting lead variants...
# 2024/10/16 16:06:44  -Found 17 significant variants in total...
# 2024/10/16 16:06:45  -Identified 2 lead variants!
# 2024/10/16 16:06:45 Finished extracting lead variants.
#               SNPID  CHR        POS      BETA        SE             P   STATUS
# 422148   rs61814953    1  205910080 -0.383004  0.065825  5.936145e-09  9999999
# 7188899   rs3788766   23  115566839 -0.404346  0.056958  1.256439e-12  9999999

# %% [markdown]
# Make a simple Manhattan and QQ plot
# skip=2 starts Y-axis to 2

# %%
mysumstats.plot_mqq(skip=2,anno=True)
# Out:
# 2024/10/16 16:06:49 Start to create MQQ plot...v3.4.48:
# 2024/10/16 16:06:49  -Genomic coordinates version: 99...
# 2024/10/16 16:06:49  #WARNING! Genomic coordinates version is unknown.
# 2024/10/16 16:06:49  -Genome-wide significance level to plot is set to 5e-08 ...
# 2024/10/16 16:06:49  -Raw input contains 7245292 variants...
# 2024/10/16 16:06:49  -MQQ plot layout mode is : mqq
# 2024/10/16 16:06:52 Finished loading specified columns from the sumstats.
# 2024/10/16 16:06:52 Start data conversion and sanity check:
# 2024/10/16 16:06:53  -Removed 0 variants with nan in CHR or POS column ...
# 2024/10/16 16:06:54  -Removed 0 variants with CHR <=0...
# 2024/10/16 16:06:55  -Removed 0 variants with nan in P column ...
# 2024/10/16 16:06:55  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2024/10/16 16:06:56  -Sumstats P values are being converted to -log10(P)...
# ...

# %% [markdown]
# The following code identifies the top SNP hit.
#
# Extract lead variants: get_lead()
#
# build="19" uses the GRCh37/hg19 (Human Reference Genome 19)
#
#
# Source: https://cloufield.github.io/gwaslab/tutorial_3.4/#extract-lead-variants-get_lead

# %%
mysumstats.get_lead(anno=True, build="19")
# Out:
# 2024/10/16 16:07:34 Start to extract lead variants...v3.4.48
# 2024/10/16 16:07:35  -Current Dataframe shape : 7245292 x 7 ; Memory usage: 379.24 MB
# 2024/10/16 16:07:35  -Processing 7245292 variants...
# 2024/10/16 16:07:35  -Significance threshold : 5e-08
# 2024/10/16 16:07:35  -Sliding window size: 500  kb
# 2024/10/16 16:07:43  -Using P for extracting lead variants...
# 2024/10/16 16:07:43  -Found 17 significant variants in total...
# 2024/10/16 16:07:43  -Identified 2 lead variants!
# 2024/10/16 16:07:43  -Annotating variants using references:ensembl
# 2024/10/16 16:07:43  -Annotating variants using references based on genome build:19
# 2024/10/16 16:07:43 Start to annotate variants with nearest gene name(s)...
# 2024/10/16 16:07:43  -Assigning Gene name using ensembl_hg19_gtf for protein coding genes
# 2024/10/16 16:07:43 Finished annotating variants with nearest gene name(s) successfully!
# 2024/10/16 16:07:43 Finished extracting lead variants.
# ...

# %%
mysumstats.summary()
# Out:
#                                                     Values  Percentage
# Category Items
# META     Row_num                                   2506477        <NA>
#          Column_num                                      7        <NA>
#          Column_names       SNPID,CHR,POS,BETA,SE,P,STATUS        <NA>
#          Last_checked_time        Wed Oct 16 16:05:34 2024        <NA>
# MISSING  Missing_total                                   1         0.0
#          Missing_P                                       1         0.0
# P        Minimum                      5.93614524202479e-09         0.0
#          Significant                                     8         0.0
#          Suggestive                                     27         0.0
# STATUS   9999999                                   2506477       100.0
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['Values'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %% [markdown]
# Another Manhattan plot

# %%
mysumstats.plot_mqq(mode="mqq",
                    build="19",
                    cut=20,
                    skip=2,
                    anno="GENENAME",
                    sig_level_lead=1e-20,
                    anno_alias={"9:22132729_A_G":"some annotations"},
                    anno_style="expand",
                    xpad=0.01,
                    pinpoint=["9:22132729_A_G","5:176513896_C_A"],
                    pinpoint_color="green",
                    highlight=["7:127253550_C_T","19:46166604_C_T"],
                    highlight_windowkb =1000,
                    stratified=True,
                    jagged=True,
                    marker_size=(5,5),
                    figargs={"figsize":(15,5),"dpi":300},
                    save="my_first_mqq_plot.png",
                    save_args={"dpi":400,"facecolor":"white"})
# Out:
# 2024/10/16 16:08:06 Start to create MQQ plot...v3.4.48:
# 2024/10/16 16:08:06  -Genomic coordinates version: 19...
# 2024/10/16 16:08:06  -Genome-wide significance level to plot is set to 5e-08 ...
# 2024/10/16 16:08:06  -Raw input contains 7245292 variants...
# 2024/10/16 16:08:06  -MQQ plot layout mode is : mqq
# 2024/10/16 16:08:06  -Loci to highlight (#CB132D): 7:127253550_C_T,19:46166604_C_T
# 2024/10/16 16:08:06   -highlight_windowkb is set to:  1000  kb
# 2024/10/16 16:08:06  -Variants to pinpoint (green) : 9:22132729_A_G,5:176513896_C_A
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %% [markdown]
# # New Section
